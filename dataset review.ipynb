# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import warnings
warnings.filterwarnings('ignore')
import plotly.express as px

# %%
# df1 = pd.read_csv('cellphones.csv')

# %%
df2 = pd.read_csv('Airline Dataset.csv')
# df3 = pd.read_csv('fake_job_postings.csv')
df4 = pd.read_csv('application_record.csv')
df5 = pd.read_csv('Covid Data.csv')
# df6 = pd.read_csv('Tesla Deaths - Deaths (3).csv')

# %%
df1.head(3)
# Out:
#     brand                      model   launch weight display type  \
# 0  Huawei     mate rs porsche design  2018-03    183         OLED
# 1  Huawei  mate 20 rs porsche design  2018-10    187         OLED
# 2   Nokia                  8 sirocco  2018-02    177       P-OLED
#
#    display size  ppi                                     chip  \
# 0          6.00  538                        Kirin 970 (10 nm)
# 1          6.39  538                         Kirin 980 (7 nm)
# 2          5.50  534  Qualcomm MSM8998 Snapdragon 835 (10 nm)
#
#                                                  cpu            gpu  \
# 0  Octa-core (4x2.4 GHz Cortex-A73 & 4x1.8 GHz Co...  Mali-G72 MP12
# 1  Octa-core (2x2.6 GHz Cortex-A76 & 2x1.92 GHz C...  Mali-G76 MP10
# 2        Octa-core (4x2.5 GHz Kryo & 4x1.8 GHz Kryo)     Adreno 540
#
#                        internal main camera  wide  telephoto selfie  battery
# 0  256GB 6GB RAM, 512GB 6GB RAM     40+8+20     1          1     24     4000
# ...

# %%
df1.shape
# Out:
# (221, 16)

# %%
df1.isna().sum()
# Out:
# brand           0
# model           0
# launch          0
# weight          0
# display type    0
# display size    0
# ppi             0
# chip            0
# cpu             0
# gpu             0
# internal        0
# main camera     0
# wide            0
# telephoto       0
# selfie          0
# battery         0
# dtype: int64

# %%
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
df2.head()
# Out:
#    Passenger ID First Name Last Name  Gender  Age Nationality  \
# 0         10856     Edithe    Leggis  Female   62       Japan
# 1         43872     Elwood      Catt    Male   62   Nicaragua
# 2         42633      Darby   Felgate    Male   67      Russia
# 3         78493   Dominica      Pyle  Female   71       China
# 4         82072        Bay   Pencost    Male   21       China
#
#                 Airport Name Airport Country Code   Country Name  \
# 0           Coldfoot Airport                   US  United States
# 1          Kugluktuk Airport                   CA         Canada
# 2     Grenoble-Isère Airport                   FR         France
# 3  Ottawa / Gatineau Airport                   CA         Canada
# 4            Gillespie Field                   US  United States
#
#   Airport Continent     Continents Departure Date Arrival Airport  \
# 0               NAM  North America      6/28/2022             CXF
# ...

# %%
df2.shape
# Out:
# (98619, 15)

# %%
df2.nunique()
# Out:
# Passenger ID            59871
# First Name               8437
# Last Name               41658
# Gender                      2
# Age                        90
# Nationality               240
# Airport Name             9062
# Airport Country Code      235
# Country Name              235
# Airport Continent           6
# Continents                  6
# Departure Date            364
# Arrival Airport          9024
# Pilot Name              98610
# Flight Status               3
# dtype: int64

# %%
df4.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008805           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008808           F            N               Y             0
# 4  5008809           F            N               Y             0
#
#    AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          427500.0               Working               Higher education
# 1          427500.0               Working               Higher education
# 2          112500.0               Working  Secondary / secondary special
# 3          270000.0  Commercial associate  Secondary / secondary special
# 4          270000.0  Commercial associate  Secondary / secondary special
#
#      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# ...

# %%
df4.isna().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        134203
# CNT_FAM_MEMBERS             0
# dtype: int64

# %%
df4.shape
# Out:
# (438557, 18)

# %%
df4.nunique()
# Out:
# ID                     438510
# CODE_GENDER                 2
# FLAG_OWN_CAR                2
# FLAG_OWN_REALTY             2
# CNT_CHILDREN               12
# AMT_INCOME_TOTAL          866
# NAME_INCOME_TYPE            5
# NAME_EDUCATION_TYPE         5
# NAME_FAMILY_STATUS          5
# NAME_HOUSING_TYPE           6
# DAYS_BIRTH              16379
# DAYS_EMPLOYED            9406
# FLAG_MOBIL                  1
# FLAG_WORK_PHONE             2
# FLAG_PHONE                  2
# FLAG_EMAIL                  2
# OCCUPATION_TYPE            18
# CNT_FAM_MEMBERS            13
# dtype: int64

# %%
df5.head()
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df5.corr(),annot=True)
plt.show()

# %%
df5.shape
# Out:
# (1048575, 21)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sqlite3 as sql
import matplotlib.pyplot as plt
import seaborn as sns
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
path = "sql-murder-mystery.db"
database = path

# %%
conn = sql.connect(database)

person = pd.read_sql_query("""SELECT *
                        FROM person""", conn)
person
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
income = pd.read_sql_query("""SELECT *
                        FROM crime_scene_report""", conn)
income
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
driver = pd.read_sql_query("""SELECT *
                        FROM drivers_license""", conn)
driver
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# !pip install pymysql

# %%
from pymysql import connect

# %%
data_base = connect(host='localhost',user='root',password='noohinaaz96')

# %%
cur = data_base.cursor()

# %%
query = 'show databases'

# %%
cur.execute(query)
# Out:
# 11

# %%
data_bases = cur.fetchall()
for data in data_bases:
    print(data)
# Out:
# ('employees',)
# ('farmers_market',)
# ('imdb',)
# ('information_schema',)
# ('medal',)
# ('murder',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sys',)
# ('target',)

# %%
data_base = connect(host='localhost',user='root',password='noohinaaz96',database = 'target')
cur = data_base.cursor()
query = 'show tables'
cur.execute(query)
tables = cur.fetchall()
print(tables)
# Out:
# (('customers',), ('geolocation',), ('order_items',), ('order_reviews',), ('orders',), ('payments',), ('products',), ('sellers',))

# %% [markdown]
# ##### `1.Import the dataset and do usual exploratory analysis steps like checking the structure & characteristics of the dataset:`
#
# - Data type of all columns in the "customers" table.
# - Get the time range between which the orders were placed.
# - Count the Cities & States of customers who ordered during the given period.

# %%
query1 = "SHOW COLUMNS FROM customers"
query2 = "SHOW COLUMNS FROM geolocation "
query3 = "SHOW COLUMNS FROM order_items"
query4 = "SHOW COLUMNS FROM order_reviews "
query5 = "SHOW COLUMNS FROM payments"
query6 = "SHOW COLUMNS FROM orders"
query7 = "SHOW COLUMNS FROM products"
query8 = "SHOW COLUMNS FROM sellers"
cur.execute(query1)
cur.execute(query2)
cur.execute(query3)
cur.execute(query4)
cur.execute(query5)
cur.execute(query6)
cur.execute(query7)
cur.execute(query8)
col1 = pd.read_sql_query(query1,data_base)
col2 = pd.read_sql_query(query2,data_base)
col3 = pd.read_sql_query(query3,data_base)
col4 = pd.read_sql_query(query4,data_base)
col5 = pd.read_sql_query(query5,data_base)
col6 = pd.read_sql_query(query6,data_base)
col7 = pd.read_sql_query(query7,data_base)
col8 = pd.read_sql_query(query8,data_base)
data_types = pd.concat([col1,col2,col3,col4,col5,col6,col7,col8], ignore_index=True, axis=0)
data_types
# Out:
#                             Field         Type Null  Key Default Extra
# 0                     customer_id  varchar(50)   NO  PRI    None
# 1              customer_unique_id  varchar(50)  YES         None
# 2        customer_zip_code_prefix          int  YES         None
# 3                   customer_city  varchar(50)  YES         None
# 4                  customer_state  varchar(10)  YES         None
# 5     geolocation_zip_code_prefix       bigint  YES         None
# 6                 geolocation_lat       double  YES         None
# 7                 geolocation_lng       double  YES         None
# 8                geolocation_city         text  YES         None
# 9               geolocation_state         text  YES         None
# 10                       order_id  varchar(50)   NO         None
# 11                  order_item_id          int  YES         None
# 12                     product_id  varchar(50)  YES         None
# ...

# %%
query1 = "select * from customers"
cur.execute(query1)
customers = pd.read_sql_query(query1,data_base)
query2 = "select * from order_items"
cur.execute(query2)
items = pd.read_sql_query(query2,data_base)
query3 = "select * from order_reviews"
cur.execute(query3)
reviews = pd.read_sql_query(query3,data_base)
query4 = "select * from orders"
cur.execute(query4)
orders = pd.read_sql_query(query4,data_base)
query5 = "select * from payments"
cur.execute(query5)
payments = pd.read_sql_query(query5,data_base)
query6 = "select * from products"
cur.execute(query6)
products = pd.read_sql_query(query6,data_base)
query7 = "select * from sellers"
cur.execute(query7)
sellers = pd.read_sql_query(query7,data_base)
query8 = "select * from geolocation "
cur.execute(query8)
location = pd.read_sql_query(query8,data_base)

# %%
# time range between the orders were placed
query = """select min(year(order_purchase_timestamp)) as 'start time', 
max(year(order_purchase_timestamp)) as 'end time',
max(year(order_purchase_timestamp)) - min(year(order_purchase_timestamp)) as 'time period'
from target.orders """
cur.execute(query)
time= pd.read_sql_query(query,data_base)
time
# Out:
#    start time  end time  time period
# 0        2016      2018            2

# %%
# Count the Cities & States of customers who ordered during the given period.
query = """select count(distinct(customer_city)) as 'total cities',
count(distinct(customer_state)) as 'total states'
from target.customers """
cur.execute(query)
city_state= pd.read_sql_query(query,data_base)
city_state
# Out:
#    total cities  total states
# 0          4119            27

# %% [markdown]
# # `BASIC EDA`

# %%
query = "select customer_city, count(customer_city) as frequency from target.customers group by customer_city "
cur.execute(query)
city= pd.read_sql_query(query,data_base)
city = city.sort_values(by='frequency',ascending=False)[:21]
fig = px.bar(city, x='customer_city', y='frequency',color='frequency',height=400)
fig.show()
# Out:
# <div>                            <div id="a7b80fb7-b84b-46fb-9779-d188da0be410" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7b80fb7-b84b-46fb-9779-d188da0be410")) {                    Plotly.newPlot(                        "a7b80fb7-b84b-46fb-9779-d188da0be410",                        [{"alignmentgroup":"True","hovertemplate":"customer_city=%{x}<br>frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[15540,6882,2773,2131,1521,1444,1379,1245,1189,938,849,797,746,713,692,691,654,633,613,570,565],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["sao paulo","rio de janeiro","belo horizonte","brasilia","curitiba","campinas","porto alegr
# ...

# %%
query = "select review_score, count(review_score) as frequency from target.order_reviews group by review_score "
cur.execute(query)
score= pd.read_sql_query(query,data_base)
# score= score.sort_values(by='frequency',ascending=False)
# fig = px.bar(score, x='review_score', y='frequency',color='frequency',height=400)
fig = px.pie(score, values='frequency',names= 'review_score',color_discrete_sequence= px.colors.sequential.Plasma_r,height=400)
fig.show()
# Out:
# <div>                            <div id="c79ea333-349b-4c29-ba13-9a8d6197fba1" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c79ea333-349b-4c29-ba13-9a8d6197fba1")) {                    Plotly.newPlot(                        "c79ea333-349b-4c29-ba13-9a8d6197fba1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"review_score=%{label}<br>frequency=%{value}<extra></extra>","labels":[4.0,5.0,1.0,3.0,2.0],"legendgroup":"","name":"","showlegend":true,"values":[19142,57328,11424,8179,3151],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#
# ...

# %%
query = "select payment_type, sum(payment_value) as total from target.payments group by payment_type "
cur.execute(query)
money= pd.read_sql_query(query,data_base)
fig = px.bar(money, x='payment_type', y='total',height=400)
fig.show()
# Out:
# <div>                            <div id="26a9c7eb-6f38-4a87-b7c7-e42b845879e2" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26a9c7eb-6f38-4a87-b7c7-e42b845879e2")) {                    Plotly.newPlot(                        "26a9c7eb-6f38-4a87-b7c7-e42b845879e2",                        [{"alignmentgroup":"True","hovertemplate":"payment_type=%{x}<br>total=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["credit_card","UPI","voucher","debit_card","not_defined"],"xaxis":"x","y":[12542084.189999327,2869361.2699999753,379436.8700000007,217989.7900000001,0.0],"yaxis":"y","type":"bar"}],                        {"template":
# ...

# %%
query = "select product_category, count(product_category) as frequency from target.products group by product_category "
cur.execute(query)
famous_products= pd.read_sql_query(query,data_base)
famous_products = famous_products.sort_values(by='frequency',ascending=False)
fig = px.bar(famous_products, x='product_category', y='frequency',color='frequency',height=500)
fig.show()
# Out:
# <div>                            <div id="53a3e545-a1b5-4d38-86bb-a0f4b98884e4" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53a3e545-a1b5-4d38-86bb-a0f4b98884e4")) {                    Plotly.newPlot(                        "53a3e545-a1b5-4d38-86bb-a0f4b98884e4",                        [{"alignmentgroup":"True","hovertemplate":"product_category=%{x}<br>frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[3029,2867,2657,2444,2335,1900,1639,1411,1329,1134,919,868,849,849,789,753,719,610,517,400,370,349,317,309,289,231,225,216,173,156,124,123,116,111,104,104,95,94,93,91,90,88,82,81,78,74,68,65,58,55,53,48,45,39,31,31,30,28,27,27,26,19,19,14,12,10,10,10,9,5,5,3,2,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","
# ...

# %%
query = "select payment_installments, count(payment_installments) as total from target.payments group by payment_installments "
cur.execute(query)
famous_products= pd.read_sql_query(query,data_base)
fig = px.bar(famous_products, x='payment_installments', y='total',color='total',height=300)
fig.show()
# Out:
# <div>                            <div id="d0512b26-1d45-4100-8cae-b00c5eeb48f9" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d0512b26-1d45-4100-8cae-b00c5eeb48f9")) {                    Plotly.newPlot(                        "d0512b26-1d45-4100-8cae-b00c5eeb48f9",                        [{"alignmentgroup":"True","hovertemplate":"payment_installments=%{x}<br>total=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[4268,52546,12413,10461,3920,5239,7098,5328,1626,133,644,16,74,18,23,27,15,17,3,8,1,2,5,1],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[8,1,2,3,6,5,4,10,7,12,9,13,15,24,11,18,14,20,21,17,22,0,16,23],"xaxis":"x","y":[4268,52546,12
# ...

# %%
# how many products each month
query = "select MONTH(order_purchase_timestamp) as 'month', count(order_id) as 'total purchases' from target.orders group by 1 "
cur.execute(query)
month_purchases = pd.read_sql_query(query,data_base)
fig = px.bar(month_purchases, x='month', y='total purchases',color='total purchases',height=500)
fig.show()
# Out:
# <div>                            <div id="89fd41ef-fdbb-46ae-82f0-e07ebe61322d" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89fd41ef-fdbb-46ae-82f0-e07ebe61322d")) {                    Plotly.newPlot(                        "89fd41ef-fdbb-46ae-82f0-e07ebe61322d",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>total purchases=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[4305,9343,8069,10843,8508,10573,5674,10318,9893,7544,4959,9412],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[9,4,1,8,2,5,12,7,3,11,10,6],"xaxis":"x","y":[4305,9343,8069,10843,8508,10573,5674,10318,9893,7544,4959,9412],"yaxis":"y","ty
# ...

# %%
query = "select QUARTER(order_purchase_timestamp) as 'quarter', count(order_id) as 'total purchases' from target.orders group by 1 "
cur.execute(query)
quarter_purchases = pd.read_sql_query(query,data_base)
fig = px.pie(quarter_purchases, names='quarter', values='total purchases',height=400)
fig.show()
# Out:
# <div>                            <div id="b2621ecf-b9a0-4ad0-a460-132746226ac7" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2621ecf-b9a0-4ad0-a460-132746226ac7")) {                    Plotly.newPlot(                        "b2621ecf-b9a0-4ad0-a460-132746226ac7",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"quarter=%{label}<br>total purchases=%{value}<extra></extra>","labels":[3,2,1,4],"legendgroup":"","name":"","showlegend":true,"values":[25466,29328,26470,18177],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333
# ...

# %%
query = "select seller_city, count(seller_city) as 'frequency'  from target.sellers group by 1 "
cur.execute(query)
sellers_info = pd.read_sql_query(query,data_base)
sellers_info = sellers_info.sort_values(by='frequency',ascending=False)[:21]
fig = px.bar(sellers_info, x='seller_city', y='frequency',color='frequency',height=400,title='top 21 sellers')
fig.show()
# Out:
# <div>                            <div id="6e3461ed-9412-461c-aa74-1ded372bce64" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e3461ed-9412-461c-aa74-1ded372bce64")) {                    Plotly.newPlot(                        "6e3461ed-9412-461c-aa74-1ded372bce64",                        [{"alignmentgroup":"True","hovertemplate":"seller_city=%{x}<br>frequency=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[695,127,96,68,52,50,49,45,41,40,33,32,32,32,28,28,26,23,22,21,20],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["sao paulo","curitiba","rio de janeiro","belo horizonte","ribeirao preto","guarulhos","ibitinga","santo andre","campinas",
# ...

# %% [markdown]
# ##### `2. In-depth Exploration:`
# - Is there a growing trend in the no. of orders placed over the past years?
# - Can we see some kind of monthly seasonality in terms of the no. of orders being placed?
# - During what time of the day, do the Brazilian customers mostly place their orders? (Dawn, Morning, Afternoon or Night)
#     * 0-6 hrs : Dawn
#     * 7-12 hrs : Mornings
#     * 13-18 hrs : Afternoon
#     * 19-23 hrs : Night

# %%
query = "select YEAR(order_purchase_timestamp) as 'year', count(order_id) as 'total purchases' from target.orders group by year "
cur.execute(query)
year_data = pd.read_sql_query(query,data_base)
year_data
# year_purchases = pd.read_sql_query(query,data_base)
# fig = px.pie(year_purchases, values='total purchases', names='year',height=400,title='Yearly distrubution of the number of purchases')
# fig.show()
# Out:
#    year  total purchases
# 0  2017            45101
# 1  2018            54011
# 2  2016              329

# %%
query = "select MONTH(order_purchase_timestamp) as 'month', count(order_id) as 'total purchases' from target.orders group by 1 order by 1 "
cur.execute(query)
month_data = pd.read_sql_query(query,data_base)
month_data
# Out:
#     month  total purchases
# 0       1             8069
# 1       2             8508
# 2       3             9893
# 3       4             9343
# 4       5            10573
# 5       6             9412
# 6       7            10318
# 7       8            10843
# 8       9             4305
# 9      10             4959
# 10     11             7544
# 11     12             5674

# %%
# how many products each month
query = "select YEAR(order_purchase_timestamp) as 'year', MONTH(order_purchase_timestamp) as 'month', count(order_id) as 'total purchases' from target.orders group by 1,2 "
cur.execute(query)
month_purchases = pd.read_sql_query(query,data_base)
# fig = px.bar(month_purchases, x='month', y='total purchases',color='total purchases',height=500)
fig = px.bar(month_purchases, x="month", y="total purchases", color="year")
fig.show()
fig.show()
# Out:
# <div>                            <div id="b37fe5eb-5110-4717-80f0-6d7be0a65062" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b37fe5eb-5110-4717-80f0-6d7be0a65062")) {                    Plotly.newPlot(                        "b37fe5eb-5110-4717-80f0-6d7be0a65062",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>total purchases=%{y}<br>year=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2017,2017,2018,2018,2017,2017,2017,2018,2018,2018,2018,2018,2017,2017,2017,2017,2018,2017,2017,2017,2016,2018,2018,2016,2016],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[9,4,1,8,2,5,12,7,3,2,4,5,8,11,10,3,6,1,6,7,10,9,1
# ...
